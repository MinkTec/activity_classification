# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from os.path import join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

from utils.visualize import plot_data_distribution_single, plot_data_distribution_combined

# %%
sns.set_theme(style='darkgrid')
plt.rc("axes", titlesize=20)

# %% [markdown]
# # Configs

# %%
input_dir = '/home/sander/nextcloud_minktec/timeseries_data'
input_dir = ''

if not os.path.exists(input_dir): # use nextcloud instead of downladed files from aws
    input_dir = 'input/timeseries_data'
    print("reading data from local folder \ndownloaded the latest data with aws_downloader already?")
else:
    print("reading from nextlcoud timeseries directory \nsynced to newest data?")
# Out:
# reading data from local folder
# downloaded the latest data with aws_downloader already?

# %%
timestamp_begin = '19.10.22 00:00'

# %%
csv_paths = [csv_path for csv_path in os.listdir(input_dir) if csv_path.endswith(".csv")]
len(csv_paths)
# Out:
# 252

# %%
frame_seconds = 2

# %% [markdown]
# # Plots

# %%
plot_data_distribution_combined(input_dir=input_dir, frequency=5, frame_seconds=frame_seconds, timestamp_begin=timestamp_begin)

# %%
plot_data_distribution_combined(input_dir=input_dir, frequency=15, frame_seconds=frame_seconds, timestamp_begin=timestamp_begin)

# %%
plot_data_distribution_single(input_dir=input_dir, key_param='activity', frequency=5, frame_seconds=frame_seconds, timestamp_begin=timestamp_begin)

# %%
plot_data_distribution_single(input_dir=input_dir, key_param='activity', frequency=15, frame_seconds=frame_seconds, timestamp_begin=timestamp_begin)

# %%
plot_data_distribution_single(input_dir=input_dir, key_param='user_model', frequency=5, frame_seconds=frame_seconds, timestamp_begin=timestamp_begin)

# %%
plot_data_distribution_single(input_dir=input_dir, key_param='user_model', frequency=15, frame_seconds=frame_seconds, timestamp_begin=timestamp_begin)

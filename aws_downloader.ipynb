# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.download_timeseries import download_timeseries_data

# %%
bucket_dir = "s3://rawdata181255-dev/public/timeseries_data/"
output_dir = "input/timeseries_data"
date_begin = "19.10.22 00:00"

# %%
download_timeseries_data(bucket_dir, output_dir, date_begin)
# Out:
# file exists      --> ---
# file downloading --> +++
#
# +++ 1665072097881_samsung_SM-A528B_FT26A_5Hz_cycling_rueckweg.csv
# +++ 1665416564779_samsung_SM-A528B_FT26A_15Hz_other_muell.csv
# +++ 1665947579135_POCO_2207117BPG_FT26F_15Hz_other_Ben-bus-wob-bs-zweite-Haelfte-gerade-sitzen.csv
# +++ 1666173916383_Xiaomi_M2007J17G_FT26A_5Hz_walking_input-matrix-test.csv
# +++ 1666177837406_samsung_SM-A528B_FT26A_5Hz_walking_100-steps.csv
# +++ 1666177915040_samsung_SM-A528B_FT26A_15Hz_walking_50-steps.csv
# +++ 1666177951490_samsung_SM-A528B_FT26A_15Hz_walking_100-steps.csv
# +++ 1666178020224_samsung_SM-A528B_FT26A_5Hz_walking_50-steps.csv
# +++ 1666188728456_samsung_SM-A528B_FT26A_5Hz_cycling.csv
# +++ 1666332261811_samsung_SM-A528B_FT26A_5Hz_cycling.csv
# +++ 1666336807620_samsung_SM-A528B_FT26A_5Hz_sitting.csv
# +++ 1666337367602_samsung_SM-A528B_FT26A_5Hz_sitting.csv
# +++ 1666341685432_samsung_SM-A528B_FT26A_5Hz_other_demo.csv
# +++ 1666369289763_samsung_SM-A528B_FT26A_5Hz_cycling.csv
# ...
